# %% [markdown]
# ## Set your working directory

# %%
import os
# The jupyter notebook is launched from your $HOME directory.
# Change the working directory to your username directory under /scratch/cd82
os.chdir(os.path.expandvars("/scratch/cd82/$USER/"))

# %% [markdown]
# ## Copy the lesson notebooks

# %% [markdown]
# ### CAUTION
# If you have been participating in any of our recent machine learning workshops you may already have notebooks in this directory.

# %%
# check that your notebooks folder is empty (if it exists)
# !ls /scratch/cd82/$USER/notebooks/

# %% [markdown]
# If "No such file or directory" message, proceed to copy files

# %% [markdown]
# If files are returned:
#
# - AND you want to save the files to tarball for download
#
#
# !tar -cvzf DDMMYY_workshop_notebooks.tar.gz /scratch/cd82/$USER/notebooks
#
# - THEN delete the existing notebooks
#
#
# !rm -rf /scratch/cd82/$USER/notebooks

# %%
# cell to exececute tar or rm commands from above

# %%
### Copy the lesson notebooks

# %%
# make a new directory in your scratch folder for this workshop
# !mkdir /scratch/cd82/$USER/notebooks

# make a copy of the notebook files
# !cp /scratch/cd82/icwcnn-files/*.ipynb /scratch/cd82/$USER/notebooks/

# check the files were copied
# !ls /scratch/cd82/$USER/notebooks/

# %% [markdown]
# ## Check all libraries are loaded

# %%
import matplotlib
print('matplotlib version: ', matplotlib.__version__)
# Out:
# matplotlib version:  3.9.4

# %%
import numpy
print('numpy version: ', numpy.__version__)
# Out:
# numpy version:  1.24.3

# %%
import pandas
print('pandas version: ', pandas.__version__)
# Out:
# pandas version:  2.3.1

# %%
import seaborn
print('seaborn version: ', seaborn.__version__)
# Out:
# seaborn version:  0.13.2

# %%
import sklearn
print('sklearn version: ', sklearn.__version__)
# Out:
# sklearn version:  1.6.1

# %%
import scikeras
print('scikeras version: ', scikeras.__version__)
# Out:
# scikeras version:  0.12.0

# %%
import tensorflow
print('Tensorflow version: ', tensorflow.__version__)
# Out:
# Tensorflow version:  2.13.1

# %%
# if you receive a "ModuleNotFoundError: No module named 'scikeras'" message, 
# try installing the pacakge manually
#!pip install <package>

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
